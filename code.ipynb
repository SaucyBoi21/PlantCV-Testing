# %%
from plantcv import plantcv as pcv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
tf.__version__
from PIL import Image

# %%
def plot(image):
    return plt.imshow(image)

# %%
#filepath = "/Users/shilo/Downloads/plantcvtest.jpeg"
filepath = "C:\\Users\\saaha\\OneDrive\\Documents\\GitHub\\PlantCV-Testing\\images\\plantcvtest.jpeg"
img, path, filename = pcv.readimage(filename=filepath)
plot(img)

# %%
s = pcv.rgb2gray_hsv(rgb_img=img, channel='s')
plot(s)

# %%
h = pcv.rgb2gray_hsv(rgb_img=img, channel='h')
plot(h)

# %%
v = pcv.rgb2gray_hsv(rgb_img=img, channel='v')
plot(v)

# %%
img_binary_thresh = pcv.threshold.binary(gray_img=s, threshold=100, max_value=255, object_type='light')
plot(img_binary_thresh)
