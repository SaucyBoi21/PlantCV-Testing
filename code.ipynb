# %%
from plantcv import plantcv as pcv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
tf.__version__
from PIL import Image

# %%
def plot_img(image):
    plt.imshow(image)

# %%
filepath = "/Users/shilo/Downloads/plantcvtest.jpeg"
sample_image =  mpimg.imread(filepath)
img = plot_img(sample_image)

# %%
gray_img = pcv.rgb2gray(rgb_img=img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 gray_img = pcv.rgb2gray(rgb_img=img)
#
# File ~/Documents/GitHub/PlantCV-Testing/venv/lib/python3.8/site-packages/plantcv/plantcv/rgb2gray.py:21, in rgb2gray(rgb_img)
#       9 def rgb2gray(rgb_img):
#      10     """Convert image from RGB colorspace to Gray.
#      11
#      12     Inputs:
#    (...)
#      19     :return gray: numpy.ndarray
#      20     """
# ---> 21     gray = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2GRAY)
#      23     _debug(visual=gray, filename=os.path.join(params.debug_outdir, str(params.device) + "_gray.png"))
#      25     return gray
#
# error: OpenCV(4.7.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
